# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
tips = sns.load_dataset("tips")

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3714/3870928973.py in <cell line: 0>()
# ----> 1 data.head()
#
# NameError: name 'data' is not defined

# %%
sns.barplot(x="tip",y="sex",data = tips)

# %%
sns.lineplot(x="total_bill",y="tip",data = tips)
plt.title("total bill vs tip size",fontsize = 20)
plt.xlabel("total bill",fontsize = 15)
plt.ylabel("tip",fontsize = 15
plt.figure(figsize=(10,10))

# %%
sns.scatterplot(x="total_bill",y="tip",data = tips)

# %%
sns.histplot(x = "tip",data = tips)

# %%
sns.kdeplot(x="tip",data = tips)

# %%
corr = tips[["total_bill","tip","size"]].corr()
sns.heatmap(corr)

# %%
corr = tips[["total_bill","tip","size"]].corr()
sns.heatmap(corr, annot=True)

# %%
sns.clustermap(x="total_bill",y="tip",data = tips)
